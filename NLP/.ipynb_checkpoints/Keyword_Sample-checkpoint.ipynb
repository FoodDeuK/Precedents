# %%
import numpy as np
import itertools
import sqlite3
import os
import re

from konlpy.tag import Okt
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from sentence_transformers import SentenceTransformer

# %%
conn_src = sqlite3.connect("../Precedents.db")
conn_dst = sqlite3.connect("../Precedents_Keyword.db")
curs_src = conn_src.cursor()
curs_dst = conn_dst.cursor()

sql = "SELECT * FROM Precedents_IC"
curs_src.execute(sql)

fetchedData = curs_src.fetchall()
length = len(fetchedData)
fetchedData = [list(fetchedData[x]) for x in range(length)]

# %%
for x in range(length):
    filepath = "C:/Temp/Cases/판례내용/{}.txt".format(fetchedData[x][0])
    
    if os.path.getsize(filepath) != 0:
        with open(filepath) as file:
            doc = file.read()
    
        okt = Okt()
        tokenized_doc = okt.pos(doc)
        tokenized_nouns = ' '.join([word[0] for word in tokenized_doc if word[1] == 'Noun'])

        n_gram_range = (2, 3)

        count = CountVectorizer(ngram_range=n_gram_range).fit([tokenized_nouns])
        candidates = count.get_feature_names_out()

        print('trigram 개수 :',len(candidates))
        print('trigram 다섯개만 출력 :',candidates[:5])

        model = SentenceTransformer('sentence-transformers/xlm-r-100langs-bert-base-nli-stsb-mean-tokens')
        doc_embedding = model.encode([doc])
        candidate_embeddings = model.encode(candidates)

        top_n = 30
        distances = cosine_similarity(doc_embedding, candidate_embeddings)
        keyword = [candidates[index] for index in distances.argsort()[0][-top_n:]]

    else:
        keyword = "내용없음"
    
    curs_dst.execute(f"INSERT INTO Precedents_Keyword Values (\"{fetchedData[x][0]}\", \"{keyword}\")")
# Out:
# trigram 개수 : 883
# trigram 다섯개만 출력 : ['개인정보 내용' '개인정보 내용 성격' '개인정보 보호' '개인정보 보호 위반' '개인정보 보호 준용']
# trigram 개수 : 1232
# trigram 다섯개만 출력 : ['가입 이용자' '가입 이용자 적용' '가입 접근' '가입 접근 사건' '가입 회원']
# trigram 개수 : 933
# trigram 다섯개만 출력 : ['개념 구성' '개념 구성 원칙' '개념 형사법' '개념 형사법 고의범' '개인 자유']
# trigram 개수 : 247
# trigram 다섯개만 출력 : ['강국 국선' '강국 국선 원심판결' '개월 집행유예' '개월 집행유예 사회봉사명령' '개인정보 종류']
# trigram 개수 : 686
# trigram 다섯개만 출력 : ['간인 공소장' '간인 공소장 형식' '간인 누락' '간인 누락 공소제기' '간인 범죄']
# trigram 개수 : 538
# trigram 다섯개만 출력 : ['가입 금제' '가입 금제 판매' '가입 범죄' '가입 범죄 일람표' '가입 일로']
# trigram 개수 : 1433
# trigram 다섯개만 출력 : ['가납 항소' '가납 항소 이유' '가능성 공연' '가능성 공연 성의' '가능성 공연 인정']
# trigram 개수 : 827
# trigram 다섯개만 출력 : ['강력 근무' '강력 근무 개인정보처리자' '개인 규정' '개인 규정 법인격' '개인 대리인']
# trigram 개수 : 605
# trigram 다섯개만 출력 : ['가액 추징' '가액 추징 규정' '가액 추징 형법' '개념 정의' '개념 정의 사정']
# trigram 개수 : 764
# trigram 다섯개만 출력 : ['가꼬온 엄마' '가꼬온 엄마 지랄' '가납 명령' '가납 명령 형사소송법' '가납 범죄사실']
# trigram 개수 : 487
# trigram 다섯개만 출력 : ['가장 선거범' '가장 선거범 여부' '가장 처벌' '가장 처벌 처벌' '검사 법무법인']
# trigram 개수 : 749
# trigram 다섯개만 출력 : ['가납 원심판결' '가납 원심판결 추징' '가납 피고인' '가납 피고인 추징' '가석방 집행']
# trigram 개수 : 1216
# trigram 다섯개만 출력 : ['가공 의사' '가공 의사 객관' '가공 의사 부인' '가공 의사 인정' '가공 의사 타인']
# trigram 개수 : 6467
# trigram 다섯개만 출력 : ['가공 의사' '가공 의사 의사' '가능성 내포' '가능성 내포 고려' '가담 공범']
# trigram 개수 : 594
# trigram 다섯개만 출력 : ['가지 사정' '가지 사정 종합' '가진 문서' '가진 문서 해당' '각각 피고인']
# trigram 개수 : 608
# trigram 다섯개만 출력 : ['가중처벌 법률' '가중처벌 법률 위반' '가지 처리' '가지 처리 경우' '감소 멸실']
# trigram 개수 : 313
# trigram 다섯개만 출력 : ['개인 신상' '개인 신상 사건' '객관 의미' '객관 의미 실상' '거나 비방']
# trigram 개수 : 3368
# trigram 다섯개만 출력 : ['가격 숙박' '가격 숙박 가격' '가격 영업' '가격 영업 공개' '가격 영업 상황']
# trigram 개수 : 803
# trigram 다섯개만 출력 : ['가해 의사' '가해 의사 목적' '감독기관 수사기관' '감독기관 수사기관 신고' '감안 동시']
# trigram 개수 : 1800
# trigram 다섯개만 출력 : ['가령 개인정보' '가령 개인정보 제공' '감독 개인정보' '감독 개인정보 수집' '감독 개인정보 처리']
# trigram 개수 : 648
# trigram 다섯개만 출력 : ['가진 프로그램' '가진 프로그램 이하' '거나 운용' '거나 운용 방해' '거나 유포']
# trigram 개수 : 1492
# trigram 다섯개만 출력 : ['가능성 모든' '가능성 모든 개인' '가치 목적' '가치 목적 개인정보' '각각 댓글']
# trigram 개수 : 1492
# trigram 다섯개만 출력 : ['가능성 모든' '가능성 모든 개인' '가치 목적' '가치 목적 개인정보' '각각 댓글']
# trigram 개수 : 468
# trigram 다섯개만 출력 : ['가입 다음' '가입 다음 오픈' '가입 승인' '가입 승인 방법' '가입 유도']
# trigram 개수 : 49217
# trigram 다섯개만 출력 : ['가가 국정원장' '가가 국정원장 노출' '가가 노출' '가가 노출 소외' '가가 노출 호텔']
# trigram 개수 : 1950
# trigram 다섯개만 출력 : ['가납 명령' '가납 명령 형사소송법' '가납 사건' '가납 사건 공소' '가상 화폐']
# trigram 개수 : 1139
# trigram 다섯개만 출력 : ['가맹점 계약' '가맹점 계약 신용카드회원' '가맹점 대금' '가맹점 대금 지급' '가맹점 대한']
# trigram 개수 : 1316
# trigram 다섯개만 출력 : ['가공 공범관계' '가공 공범관계 공모' '가공 범죄' '가공 범죄 실현' '가납 명령']
# trigram 개수 : 744
# trigram 다섯개만 출력 : ['가능성 문제' '가능성 문제 사용' '가능성 정도' '가능성 정도 구체성' '가치나 평가']
# trigram 개수 : 548
# trigram 다섯개만 출력 : ['가동 어뷰징' '가동 어뷰징 필터' '거나 운용' '거나 운용 방해' '검사 법무법인']
# trigram 개수 : 939
# trigram 다섯개만 출력 : ['가입 네이버' '가입 네이버 밴드' '가해 의사' '가해 의사 목적' '갈등 대립']
# trigram 개수 : 140600
# trigram 다섯개만 출력 : ['가가 노출' '가가 노출 때문' '가가 마련' '가가 마련 지시' '가가 수사기록']
# trigram 개수 : 1665
# trigram 다섯개만 출력 : ['가능성 거의' '가능성 거의 또한' '가입 아이디' '가입 아이디 게재' '가입 회원']
# trigram 개수 : 10016
# trigram 다섯개만 출력 : ['가까이 피고인' '가까이 피고인 또한' '가납 명령' '가납 명령 형사소송법' '가납 피고인']
# trigram 개수 : 2066
# trigram 다섯개만 출력 : ['가납 고단' '가납 고단 피고인' '가납 명령' '가납 명령 피고인' '가리개 기능']
# trigram 개수 : 549
# trigram 다섯개만 출력 : ['개월 선고' '개월 선고 사실관계' '개월 집행유예' '개월 집행유예 선고' '개정 시행']
# trigram 개수 : 538
# trigram 다섯개만 출력 : ['가입 자동' '가입 자동 방문' '간접 접속' '간접 접속 네이버' '개정 전의']
# trigram 개수 : 691
# trigram 다섯개만 출력 : ['가장 관건' '가장 관건 실체' '가장 방식' '가장 방식 증거조사' '가장 직접']
# trigram 개수 : 1177
# trigram 다섯개만 출력 : ['가가 소외' '가가 소외 그룹' '가납 명령' '가납 명령 형사소송법' '가납 피고인']
# trigram 개수 : 964
# trigram 다섯개만 출력 : ['가지 제목' '가지 제목 음란물' '간과 공판절차' '간과 공판절차 진행' '간인 교합']
# trigram 개수 : 1547
# trigram 다섯개만 출력 : ['간의 관계' '간의 관계 피고인' '간의 상품권' '간의 상품권 할인' '감독 사항']
# trigram 개수 : 1094
# trigram 다섯개만 출력 : ['가가 원고' '가가 원고 계약' '가가 위약금' '가가 위약금 손해' '가관 가액']
# trigram 개수 : 1751
# trigram 다섯개만 출력 : ['가기 문자메시지' '가기 문자메시지 피해자' '가까이 취지' '가까이 취지 사실' '가까이 피해자']
# trigram 개수 : 669
# trigram 다섯개만 출력 : ['간의 성교' '간의 성교 행위' '개설 운영' '개설 운영 웹사이트' '거나 연하']
# trigram 개수 : 551
# trigram 다섯개만 출력 : ['감리 업종' '감리 업종 별로' '감리 영업' '감리 영업 소방시설업자' '개설 이전']
# trigram 개수 : 817
# trigram 다섯개만 출력 : ['가목 신상정보' '가목 신상정보 등록' '가족 피고인' '가족 피고인 대한' '거나 장애인복지시설']
# trigram 개수 : 1632
# trigram 다섯개만 출력 : ['가납 명령' '가납 명령 형사소송법' '가납 항소' '가납 항소 이유' '개인정보 보호']
# trigram 개수 : 633
# trigram 다섯개만 출력 : ['가능성 용인' '가능성 용인 원심판결' '각종 매체물' '각종 매체물 시청' '개별 사안']
# trigram 개수 : 416
# trigram 다섯개만 출력 : ['개별 도급계약' '개별 도급계약 체결' '검토 원심' '검토 원심 판단' '결론 피고인']
# trigram 개수 : 9162
# trigram 다섯개만 출력 : ['가공 진실' '가공 진실 확신' '가납 명령' '가납 명령 피고인' '가납 사건']
# trigram 개수 : 376
# trigram 다섯개만 출력 : ['가지 사정' '가지 사정 종합' '게시 영상' '게시 영상 자체' '견해 다소']
# trigram 개수 : 1434
# trigram 다섯개만 출력 : ['가족관계 환경' '가족관계 환경 사건' '가지 따라서' '가지 따라서 피고인' '가진 악성프로그램']
# trigram 개수 : 595
# trigram 다섯개만 출력 : ['가지 사건' '가지 사건 문자메시지' '가치 발견' '가치 발견 원심' '가치 지니']
# trigram 개수 : 887
# trigram 다섯개만 출력 : ['가정 환경' '가정 환경 범행' '가족 피고인' '가족 피고인 관계' '가족 피고인 대한']
# trigram 개수 : 1119
# trigram 다섯개만 출력 : ['가공 저장' '가공 저장 검색' '각자 컴퓨터' '각자 컴퓨터 설치' '개념 고려']
# trigram 개수 : 850
# trigram 다섯개만 출력 : ['가능성 표현' '가능성 표현 명예훼손' '가진 사안' '가진 사안 표현' '가치나 평가']
# trigram 개수 : 398
# trigram 다섯개만 출력 : ['객관 인식' '객관 인식 상태' '결론 피고인' '결론 피고인 상고' '경범죄 처벌']
# trigram 개수 : 779
# trigram 다섯개만 출력 : ['가입 네이버' '가입 네이버 밴드' '감정 표현' '감정 표현 내용' '개인 감정']
# trigram 개수 : 676
# trigram 다섯개만 출력 : ['감안 사정' '감안 사정 따라서' '객관 상태' '객관 상태 경우' '객관 상태 법률상']
# trigram 개수 : 514
# trigram 다섯개만 출력 : ['거나 촬영' '거나 촬영 반포' '경우 달리' '경우 달리 근거' '경우 사후']
# trigram 개수 : 777
# trigram 다섯개만 출력 : ['가능성 미국' '가능성 미국 가습기' '가량 메탄올' '가량 메탄올 식품의약품안전처' '가습기 살균제']
# trigram 개수 : 638
# trigram 다섯개만 출력 : ['가상 화폐' '가상 화폐 일종' '가치 디지털로' '가치 디지털로 표상' '가치 무형']
# trigram 개수 : 358
# trigram 다섯개만 출력 : ['가입 인터넷' '가입 인터넷 커뮤니티' '가장 게시' '가장 게시 행위' '가장 커뮤니티']
# trigram 개수 : 798
# trigram 다섯개만 출력 : ['가연 김지영' '가장 방법' '가장 방법 경제' '가족관계 범행' '가족관계 범행 후의']
# trigram 개수 : 10361
# trigram 다섯개만 출력 : ['가공 공범관계' '가공 공범관계 공모' '가공 범죄' '가공 범죄 실현' '가공 의사']
# trigram 개수 : 634
# trigram 다섯개만 출력 : ['개인 자유' '개인 자유 권리' '거기 논리' '거기 논리 경험칙' '거기 성폭력']
# trigram 개수 : 2910
# trigram 다섯개만 출력 : ['가까이 밀착' '가까이 밀착 피고인' '가납 명령' '가납 명령 형사소송법' '가납 범죄사실']
# trigram 개수 : 3280
# trigram 다섯개만 출력 : ['가계 현재' '가계 현재 피고인' '가능성 소외' '가능성 소외 소외' '가능성 앞서']
# trigram 개수 : 3280
# trigram 다섯개만 출력 : ['가계 현재' '가계 현재 피고인' '가능성 소외' '가능성 소외 소외' '가능성 앞서']
# trigram 개수 : 1131
# trigram 다섯개만 출력 : ['가능성 신문' '가능성 신문 진흥' '가치 판단' '가치 판단 합리' '간격 분할']
# trigram 개수 : 2760
# trigram 다섯개만 출력 : ['가능성 정보통신서비스' '가능성 정보통신서비스 제공자' '가량 증가' '가량 증가 파일' '가로 해킹']
# trigram 개수 : 322
# trigram 다섯개만 출력 : ['개인정보 누설' '개인정보 누설 거나' '개인정보 보호' '개인정보 보호 개인정보' '개인정보 보호 입법']
# trigram 개수 : 417
# trigram 다섯개만 출력 : ['것임 자의' '것임 자의 스스로' '게시 사진' '게시 사진 전시' '게시 성적']
# trigram 개수 : 2738
# trigram 다섯개만 출력 : ['가능성 인터넷' '가능성 인터넷 통해' '가족관계 범행' '가족관계 범행 동기' '가중처벌 규정']
# trigram 개수 : 807
# trigram 다섯개만 출력 : ['거래 당시' '거래 당시 피고인' '것일 상품권' '것일 상품권 할인' '게시 보고']
# trigram 개수 : 1866
# trigram 다섯개만 출력 : ['가격 게시' '가격 게시 피고인' '가공 저장' '가공 저장 검색' '가능성 유무']
# trigram 개수 : 1623
# trigram 다섯개만 출력 : ['가공 의사' '가공 의사 의사' '가담 기간' '가담 기간 내지' '가담 범위']
# trigram 개수 : 1985
# trigram 다섯개만 출력 : ['가장 초적' '가장 초적 모습' '가치 대하' '가치 대하 상세' '가치 왜곡']
# trigram 개수 : 2230
# trigram 다섯개만 출력 : ['가능성 절차' '가능성 절차 조항' '가운데 도리어' '가운데 도리어 유죄' '가운데 사건']
# trigram 개수 : 2457
# trigram 다섯개만 출력 : ['가능 여부' '가능 여부 체크' '가능 프로그램' '가능 프로그램 생략' '가능성 배제']
# trigram 개수 : 658
# trigram 다섯개만 출력 : ['각자 컴퓨터' '각자 컴퓨터 설치' '거기 피고인' '거기 피고인 주장' '거치 임의']
# trigram 개수 : 936
# trigram 다섯개만 출력 : ['가장 체계' '가장 체계 합리' '가치 비밀' '가치 비밀 관리' '개인정보 누설']
# trigram 개수 : 416
# trigram 다섯개만 출력 : ['검사 공소장변경' '검사 공소장변경 신청' '검사 공소장변경 허가' '검사 피고인' '검사 피고인 대한']
# trigram 개수 : 6205
# trigram 다섯개만 출력 : ['가감 기간' '가감 기간 부분' '가게 가게' '가게 가게 거의' '가게 거의']
# trigram 개수 : 1557
# trigram 다섯개만 출력 : ['가납 명령' '가납 명령 피고' '가납 범죄사실' '가납 범죄사실 기초' '가치판단 보기']
# trigram 개수 : 3550
# trigram 다섯개만 출력 : ['가능성 대량' '가능성 대량 개인정보' '가능성 소비자' '가능성 소비자 입장' '가능성 응모']
# trigram 개수 : 4723
# trigram 다섯개만 출력 : ['가공 매출' '가공 매출 자료' '가관 뇌물수수죄' '가관 뇌물수수죄 성립' '가관 부당한']
# trigram 개수 : 648
# trigram 다섯개만 출력 : ['강용 공판' '강용 공판 변호사' '개정 전의' '개정 전의 카메라' '개정 조문']
# trigram 개수 : 1162
# trigram 다섯개만 출력 : ['가공 대출' '가공 대출 중개업' '가지 개인정보' '가지 개인정보 교환' '개괄 표시']
# trigram 개수 : 466
# trigram 다섯개만 출력 : ['가치 대한' '가치 대한 평가' '감시 비판' '감시 비판 대상' '감시 비판 대한']
# trigram 개수 : 10480
# trigram 다섯개만 출력 : ['가공 공범관계' '가공 공범관계 공모' '가공 범죄' '가공 범죄 실현' '가공 의사']
# trigram 개수 : 1807
# trigram 다섯개만 출력 : ['가지 개인' '가지 개인 단체' '가치 구체' '가치 구체 비교' '가치 행복추구권']
# trigram 개수 : 4519
# trigram 다섯개만 출력 : ['가능성 대량' '가능성 대량 개인정보' '가량 지난' '가량 지난 경이' '가사 사항']
# trigram 개수 : 1635
# trigram 다섯개만 출력 : ['가능성 실질' '가능성 실질 판단' '가장 수단' '가장 수단 다른' '간주 원고']
# trigram 개수 : 636
# trigram 다섯개만 출력 : ['가담 정도' '가담 정도 중하' '가지 양형' '가지 양형 조건' '개인정보 건당']
# trigram 개수 : 1291
# trigram 다섯개만 출력 : ['가액 산정' '가액 산정 검사' '가액 산정 균형' '가액 얼마' '가액 얼마 문제']
# trigram 개수 : 759
# trigram 다섯개만 출력 : ['가능성 개인정보' '가능성 개인정보 유출' '가치 지니' '가치 지니 물의' '가치 훼손']
# trigram 개수 : 694
# trigram 다섯개만 출력 : ['개인 개인정보처리자' '개인 개인정보처리자 정의' '개인 한정' '개인 한정 업무' '개인정보 누설']
# trigram 개수 : 4271
# trigram 다섯개만 출력 : ['가능성 대량' '가능성 대량 개인정보' '가능성 보험회사' '가능성 보험회사 수행' '가독 응모']
# trigram 개수 : 614
# trigram 다섯개만 출력 : ['가납 명령' '가납 명령 형사소송법' '가납 범죄사실' '가납 범죄사실 피고인' '개인 규정']
# trigram 개수 : 526
# trigram 다섯개만 출력 : ['강문 원심판결' '강문 원심판결 광주' '거나 반대' '거나 반대 내용' '거나 후보자']
# trigram 개수 : 868
# trigram 다섯개만 출력 : ['가납 명령' '가납 명령 형사소송법' '가납 피고인' '가납 피고인 대판' '가지 조합원']
# trigram 개수 : 880
# trigram 다섯개만 출력 : ['가지 대법원' '가지 대법원 선고' '거기 상고이유' '거기 상고이유 주장' '거기 출력']
# trigram 개수 : 8285
# trigram 다섯개만 출력 : ['가납 명령' '가납 명령 형사소송법' '가납 사건' '가납 사건 공소' '가능성 대해']
# trigram 개수 : 695
# trigram 다섯개만 출력 : ['가진 장치' '가진 장치 사용' '가치 공단' '가치 공단 보유' '가치 원심']
# trigram 개수 : 2693
# trigram 다섯개만 출력 : ['가납 명령' '가납 명령 피고인' '가납 피고인' '가납 피고인 대한' '가능성 이메일']
# trigram 개수 : 408
# trigram 다섯개만 출력 : ['가지 증명력' '가지 증명력 가진' '가진 증거' '가진 증거 증거' '간다 피고인']
# trigram 개수 : 427
# trigram 다섯개만 출력 : ['간접 모든' '간접 모든 행위' '개개 저작물' '개개 저작물 위치' '개개 저작물 직접']
# trigram 개수 : 1895
# trigram 다섯개만 출력 : ['가납 명령' '가납 명령 피고' '가납 범죄사실' '가납 범죄사실 피고인' '가담 가중']
# trigram 개수 : 547
# trigram 다섯개만 출력 : ['개인정보 타인' '개인정보 타인 비밀' '거기 논리' '거기 논리 경험' '검사 공판']
# trigram 개수 : 704
# trigram 다섯개만 출력 : ['가공 편집' '가공 편집 검색' '각각 규정' '각각 규정 한편' '개인 개인정보처리자']
# trigram 개수 : 1574
# trigram 다섯개만 출력 : ['가납 명령' '가납 명령 형사소송법' '가납 원심판결' '가납 원심판결 대한' '가장 접근']
# trigram 개수 : 1699
# trigram 다섯개만 출력 : ['가능성 용인' '가능성 용인 따라서' '가능성 인식' '가능성 인식 방조범' '가능성 인식 용인']
# trigram 개수 : 4110
# trigram 다섯개만 출력 : ['가능 노동조합' '가능 노동조합 위원장' '가량 개인' '가량 개인 여행' '가량 국외']
# trigram 개수 : 793
# trigram 다섯개만 출력 : ['개월 다만' '개월 다만 판결' '개인 정보' '개인 정보 유출' '개인 택시']
# trigram 개수 : 994
# trigram 다섯개만 출력 : ['가공 공범관계' '가공 공범관계 공모' '가공 범죄' '가공 범죄 실현' '가목 컴퓨터']
# trigram 개수 : 587
# trigram 다섯개만 출력 : ['개정 전의' '개정 전의 이하' '거나 다른' '거나 다른 사업자등' '거래 질서']
# trigram 개수 : 2092
# trigram 다섯개만 출력 : ['가장 언론' '가장 언론 매체' '가중처벌 법률' '가중처벌 법률 위반' '가중처벌 법률 형법']
# trigram 개수 : 598
# trigram 다섯개만 출력 : ['개인 대한' '개인 대한 모욕' '객관 자료' '객관 자료 확인' '거나 현저']
# trigram 개수 : 730
# trigram 다섯개만 출력 : ['가능성 명예훼손죄' '가능성 명예훼손죄 성립' '가진 사람' '가진 사람 누구' '가진 사람 대하']
# trigram 개수 : 280
# trigram 다섯개만 출력 : ['가치관 감정' '가치관 감정 범죄피해자' '감정 범죄피해자' '감정 범죄피해자 이익' '검찰 단계']
# trigram 개수 : 527
# trigram 다섯개만 출력 : ['가능성 범행' '가능성 범행 전후' '가중 사형' '가중 사형 무기' '가중처벌 법률']
# trigram 개수 : 568
# trigram 다섯개만 출력 : ['개념 법적' '개념 법적 평가' '개정 전의' '개정 전의 이하' '객관 규범']
# trigram 개수 : 564
# trigram 다섯개만 출력 : ['감독 지원' '감독 지원 규제' '감독관 질서유지' '감독관 질서유지 신분' '거기 논리']
# trigram 개수 : 2821
# trigram 다섯개만 출력 : ['가격 판매' '가격 판매 내용' '가공 범죄' '가공 범죄 실현' '가공 의사']
# trigram 개수 : 2371
# trigram 다섯개만 출력 : ['가능성 성격' '가능성 성격 피고인' '가슴 부분' '가슴 부분 가운데' '가슴 부분 왼쪽']
# trigram 개수 : 784
# trigram 다섯개만 출력 : ['가운데 경찰청' '가운데 경찰청 부여' '가운데 알림' '가운데 알림 마당' '가족 사랑방']
# trigram 개수 : 857
# trigram 다섯개만 출력 : ['가을 학기' '가을 학기 이수' '가을 학기 학기' '가지 피해자' '가지 피해자 소외']
# trigram 개수 : 1014
# trigram 다섯개만 출력 : ['가격 대응' '가격 대응 추첨' '가격 생성' '가격 생성 예비' '가격 작성']
# trigram 개수 : 977
# trigram 다섯개만 출력 : ['가장 대학교' '가장 대학교 교무' '가장 허락' '가장 허락 소외' '각종 생활']
# trigram 개수 : 445
# trigram 다섯개만 출력 : ['가중처벌 법률' '가중처벌 법률 위반' '개인정보보호법 위반' '개인정보보호법 위반 배임' '개인정보보호법 위반 법리']
# trigram 개수 : 3271
# trigram 다섯개만 출력 : ['가격 판매' '가격 판매 내용' '가공 공범관계' '가공 공범관계 공모' '가공 범죄']
# trigram 개수 : 2855
# trigram 다섯개만 출력 : ['가가 선택' '가가 선택 거나' '가공 공범관계' '가공 공범관계 공모' '가공 범죄']
# trigram 개수 : 1375
# trigram 다섯개만 출력 : ['가격 기초자산' '가격 기초자산 기초자산' '가격 이자율' '가격 이자율 지표' '가입 거래']
# trigram 개수 : 605
# trigram 다섯개만 출력 : ['가입자 전화번호' '가입자 전화번호 보유자' '개념 내지' '개념 내지 정보통신망법' '개념 법리']
# trigram 개수 : 782
# trigram 다섯개만 출력 : ['가짜 경력' '가짜 경력 사항' '가짜 박사학위' '가짜 박사학위 가짜' '개최 당시']
# trigram 개수 : 2169
# trigram 다섯개만 출력 : ['가장 개인정보' '가장 개인정보 입수' '가장 대학교' '가장 대학교 학적' '가장 불구']
# trigram 개수 : 4415
# trigram 다섯개만 출력 : ['가가 포함' '가가 포함 낙찰' '가가 표시' '가가 표시 추첨' '가공 정보']
# trigram 개수 : 6661
# trigram 다섯개만 출력 : ['가공 범죄' '가공 범죄 실현' '가능성 매우' '가능성 매우 더욱이' '가능성 미리']
# trigram 개수 : 1007
# trigram 다섯개만 출력 : ['가장 공공기관' '가장 공공기관 대학교' '가장 사실' '가장 사실 인정' '가장 피고인']
# trigram 개수 : 2228
# trigram 다섯개만 출력 : ['가공 저장' '가공 저장 검색' '가장 그로' '가장 그로 네이버' '가장 한편']
# trigram 개수 : 1105
# trigram 다섯개만 출력 : ['가공 공범관계' '가공 공범관계 공모' '가공 범죄' '가공 범죄 실현' '가공 의사']
# trigram 개수 : 3024
# trigram 다섯개만 출력 : ['가격 양질' '가격 양질 상품' '가공 의사' '가공 의사 의사' '가능성 결과']
# trigram 개수 : 1329
# trigram 다섯개만 출력 : ['가능성 여부' '가능성 여부 판단' '가정교사 로부터' '가정교사 로부터 수업' '가족 권리']
# trigram 개수 : 529
# trigram 다섯개만 출력 : ['가끔 박사' '가끔 박사 얼굴' '가지 신분' '가지 신분 마음' '가치판단 내지']
# trigram 개수 : 8234
# trigram 다섯개만 출력 : ['가공 의사' '가공 의사 가지' '가관 인정' '가관 인정 피고인' '가관 피고인']
# trigram 개수 : 928
# trigram 다섯개만 출력 : ['가상 화폐' '가상 화폐 로서' '가치 재화' '가치 재화 교환' '개정 경위']
# trigram 개수 : 1002
# trigram 다섯개만 출력 : ['가장 접근' '가장 접근 해석' '가장 체계' '가장 체계 합리' '감청 금지']
# trigram 개수 : 1124
# trigram 다섯개만 출력 : ['가해 의사' '가해 의사 목적' '객관 국민' '객관 국민 공공성' '객관 사실']
# trigram 개수 : 1159
# trigram 다섯개만 출력 : ['가능성 판단' '가능성 판단 거기' '가능성 피고인' '가능성 피고인 증언거부' '가지 요소']
# trigram 개수 : 539
# trigram 다섯개만 출력 : ['가치 발견' '가치 발견 정보통신망' '가치 지니' '가치 지니 물의' '가치 훼손']
# trigram 개수 : 1898
# trigram 다섯개만 출력 : ['가능성 가장' '가능성 가장 신체' '가능성 매우' '가능성 매우 사상' '가장 노출']
# trigram 개수 : 506
# trigram 다섯개만 출력 : ['감경 면제' '감경 면제 해석' '강요 징역' '강요 징역 징역' '거기 상고이유']
# trigram 개수 : 1682
# trigram 다섯개만 출력 : ['가담 정상' '가담 정상 고려' '가담 필요' '가담 필요 뒷받침' '가족 부양']
# trigram 개수 : 175
# trigram 다섯개만 출력 : ['게시 공공의' '게시 공공의 이익' '게시 피해자' '게시 피해자 소외' '게재 경위']
# trigram 개수 : 1189
# trigram 다섯개만 출력 : ['가능성 가장' '가능성 가장 신체' '가능성 매우' '가능성 매우 사상' '가량 차지']
# trigram 개수 : 844
# trigram 다섯개만 출력 : ['가사 피고인' '가사 피고인 유죄' '가지 정상' '가지 정상 참작' '감안 징역형']
# trigram 개수 : 540
# trigram 다섯개만 출력 : ['가납 명령' '가납 명령 형사소송법' '가납 범죄사실' '가납 범죄사실 피고인' '가해 의사']
# trigram 개수 : 550
# trigram 다섯개만 출력 : ['가능성 구체' '가능성 구체 지휘' '간접 수행' '간접 수행 법인' '감독 가능성']
# trigram 개수 : 427
# trigram 다섯개만 출력 : ['가납 명령' '가납 명령 형사소송법' '가납 범죄사실' '가납 범죄사실 피고인' '가능성 고려']
# trigram 개수 : 1307
# trigram 다섯개만 출력 : ['가능성 구체' '가능성 구체 지휘감독' '가입자 개인정보' '가입자 개인정보 사용' '가입자 개인정보 전화번호']
# trigram 개수 : 802
# trigram 다섯개만 출력 : ['각각 피고인' '각각 피고인 하루' '감염 사용자' '감염 사용자 정보통신망' '개념 실행']
# trigram 개수 : 430
# trigram 다섯개만 출력 : ['가입자 홈페이지' '가입자 홈페이지 이하' '개인 신상정보' '개인 신상정보 해당' '거기 논리']
# trigram 개수 : 891
# trigram 다섯개만 출력 : ['가입 전화번호' '가입 전화번호 소외' '가입 전화번호 용지' '가입 전화번호 자신' '가입 전화번호 피고인']
# trigram 개수 : 526
# trigram 다섯개만 출력 : ['가해 의사' '가해 의사 내지' '감안 동시' '감안 동시 표현' '객관 공공의']
# trigram 개수 : 2188
# trigram 다섯개만 출력 : ['가능성 구성원' '가능성 구성원 개개인' '가능성 대한' '가능성 대한 판단' '가능성 따라서']
# trigram 개수 : 749
# trigram 다섯개만 출력 : ['가능성 여부' '가능성 여부 대한' '가지 불구' '가지 불구 원심' '가치 여론']
# trigram 개수 : 649
# trigram 다섯개만 출력 : ['가능성 사건' '가능성 사건 문자메시지' '가능성 자체' '가능성 자체 배제' '가능성 정도']
# trigram 개수 : 862
# trigram 다섯개만 출력 : ['가입자 대한' '가입자 대한 서비스' '가입자 해지' '가입자 해지 복구' '가지 경우']
# trigram 개수 : 708
# trigram 다섯개만 출력 : ['가입 변경' '가입 변경 약관' '가입자 유치' '가입자 유치 목적' '가지 개인정보']
# trigram 개수 : 2315
# trigram 다섯개만 출력 : ['가까이 공중파' '가까이 공중파 방송' '가능성 까닭' '가능성 까닭 발언' '가량 여학생']
# trigram 개수 : 930
# trigram 다섯개만 출력 : ['가공 인터넷' '가공 인터넷 주소' '가공 정보' '가공 정보 훼손' '개념 대하']
# trigram 개수 : 677
# trigram 다섯개만 출력 : ['가해 상당한' '가해 상당한 경우' '가해 행위' '가해 행위 방어' '가해자 행위']
# trigram 개수 : 1203
# trigram 다섯개만 출력 : ['가담 범행' '가담 범행 편취액' '가담 사실' '가담 사실 인정' '가담 사실 장하나']
# trigram 개수 : 319
# trigram 다섯개만 출력 : ['개시 전인' '개시 전인 원심법원' '결과 판결' '결과 판결 영향' '결정 결정']
# trigram 개수 : 1878
# trigram 다섯개만 출력 : ['가구 증가' '가구 증가 내용' '가납 명령' '가납 명령 형사소송법' '가납 범죄사실']
# trigram 개수 : 2501
# trigram 다섯개만 출력 : ['가공 제공' '가공 제공 경우' '가납 명령' '가납 명령 피고인' '가납 항소']
# trigram 개수 : 366
# trigram 다섯개만 출력 : ['가지 정도' '가지 정도 추단' '간다 피고인' '간다 피고인 이익' '간접사실 논리']
# trigram 개수 : 294
# trigram 다섯개만 출력 : ['가치 내지' '가치 내지 평가' '감정 이유' '감정 이유 피해자' '개인 취향']
# trigram 개수 : 1119
# trigram 다섯개만 출력 : ['가처분 신청' '가처분 신청 사건' '가처분 신청 인천' '감정 싸움' '감정 싸움 과정']
# trigram 개수 : 1455
# trigram 다섯개만 출력 : ['가해 의사' '가해 의사 내지' '각각 훼손' '각각 훼손 원심' '감정 거나']
# trigram 개수 : 2350
# trigram 다섯개만 출력 : ['가경동 고속버스' '가경동 고속버스 터미널' '가담 정도' '가담 정도 다소' '가담 정도 잘못']
# trigram 개수 : 401
# trigram 다섯개만 출력 : ['가족 내용' '가족 내용 문자' '가진 미로' '가진 미로 피해자' '각각 별개']
# trigram 개수 : 857
# trigram 다섯개만 출력 : ['가지 사정' '가지 사정 종합' '가해 상당한' '가해 상당한 경우' '가해 행위']
# trigram 개수 : 209
# trigram 다섯개만 출력 : ['개설 디스크' '개설 디스크 사이트' '거기 상고이유' '거기 상고이유 주장' '검사 원심판결']
# trigram 개수 : 852
# trigram 다섯개만 출력 : ['가능성 농후' '가능성 농후 주장' '가해 의사' '가해 의사 내지' '감안 동시']
# trigram 개수 : 977
# trigram 다섯개만 출력 : ['가지 사건' '가지 사건 특허권' '가진 이하' '가진 이하 통상' '각각 선행']
# trigram 개수 : 334
# trigram 다섯개만 출력 : ['개인정보 금정산' '개인정보 금정산 목적' '개인정보 당초' '개인정보 당초 동의' '개인정보 동의']
# trigram 개수 : 2393
# trigram 다섯개만 출력 : ['가공 저장' '가공 저장 검색' '가능성 전혀' '가능성 전혀 광고주' '가담 사실']
# trigram 개수 : 1328
# trigram 다섯개만 출력 : ['가로 채무자' '가로 채무자 광고' '가처분 범위' '가처분 범위 법리' '가처분 보전']
# trigram 개수 : 203
# trigram 다섯개만 출력 : ['가납 명령' '가납 명령 형사소송법' '가납 범죄사실' '가납 범죄사실 피고인' '가진 피고인']
# trigram 개수 : 653
# trigram 다섯개만 출력 : ['가장 접근' '가장 접근 해석' '개인정보 교인' '개인정보 교인 명단' '개인정보 보호']
# trigram 개수 : 731
# trigram 다섯개만 출력 : ['가능 여부' '가능 여부 비밀번호' '가부 절차' '가부 절차 방법' '각서 작성']
# trigram 개수 : 538
# trigram 다섯개만 출력 : ['갈비뼈 복장' '갈비뼈 복장 염좌' '개새끼 씨발' '개새끼 씨발 욕설' '개설 등록']
# trigram 개수 : 1068
# trigram 다섯개만 출력 : ['가납 명령' '가납 명령 형사소송법' '가납 피고인' '가납 피고인 대한' '가능성 피고인']
# trigram 개수 : 190
# trigram 다섯개만 출력 : ['가납 명령' '가납 명령 형사소송법' '가납 범죄사실' '가납 범죄사실 누구' '개인정보 적부']
# trigram 개수 : 2150
# trigram 다섯개만 출력 : ['가격 광고' '가격 광고 광고' '가납 명령' '가납 명령 피고인' '가납 피고인']
# trigram 개수 : 485
# trigram 다섯개만 출력 : ['개정 전의' '개정 전의 이하' '거기 피해자' '거기 피해자 인영' '검찰총장 수원']
# trigram 개수 : 20184
# trigram 다섯개만 출력 : ['가격 거래' '가격 거래 조건' '가격 상담' '가격 상담 전화번호' '가격 포함']
# trigram 개수 : 396
# trigram 다섯개만 출력 : ['가지 정보' '가지 정보 계정' '가치 가지' '가치 가지 정보' '각서 작성']
# trigram 개수 : 416
# trigram 다섯개만 출력 : ['가납 명령' '가납 명령 형사소송법' '가납 범죄사실' '가납 범죄사실 피고인' '가장 실효']
# trigram 개수 : 8841
# trigram 다섯개만 출력 : ['가격 방법' '가격 방법 가격' '가격 신체' '가격 신체 부위' '가격 장소']
# trigram 개수 : 471
# trigram 다섯개만 출력 : ['강사 내지' '강사 내지 비율' '강의 내용' '강의 내용 피고인' '강의 수강생']
# trigram 개수 : 923
# trigram 다섯개만 출력 : ['가입 위성방송' '가입 위성방송 수신기' '가입 정식' '가입 정식 사건' '가입 체약국']
# trigram 개수 : 1484
# trigram 다섯개만 출력 : ['가게 유학' '가게 유학 아들' '가납 명령' '가납 명령 형법' '가납 피고인']
# trigram 개수 : 299
# trigram 다섯개만 출력 : ['가장 통상' '가장 통상 업무' '개발 유포' '개발 유포 도우미' '개정 전의']
# trigram 개수 : 279
# trigram 다섯개만 출력 : ['가납 명령' '가납 명령 형사소송법' '가납 범죄사실' '가납 범죄사실 피고인' '각서 사본']
# trigram 개수 : 1294
# trigram 다섯개만 출력 : ['가장 피해자' '가장 피해자 소외' '가족 고통' '가족 고통 매우' '가중 미결구금일수']
# trigram 개수 : 1188
# trigram 다섯개만 출력 : ['가납 명령' '가납 명령 형사소송법' '가납 항소' '가납 항소 이유' '가지 음향']
# trigram 개수 : 927
# trigram 다섯개만 출력 : ['가능성 문제' '가능성 문제 사용' '가슴 전문' '가슴 전문 지방' '가지 대해']
# trigram 개수 : 967
# trigram 다섯개만 출력 : ['가능성 공연' '가능성 공연 성의' '가능성 부정' '가능성 부정 위계' '가능성 전혀']
# trigram 개수 : 1307
# trigram 다섯개만 출력 : ['가능성 절차' '가능성 절차 조항' '가능성 투약' '가능성 투약 횟수' '가지 특정']
# trigram 개수 : 1293
# trigram 다섯개만 출력 : ['가공 의사' '가공 의사 객관' '가공 의사 공동' '가능성 절차' '가능성 절차 통한']
# trigram 개수 : 941
# trigram 다섯개만 출력 : ['가능성 절차' '가능성 절차 조항' '객관 사실관계' '객관 사실관계 모두' '검사 작성']
# trigram 개수 : 756
# trigram 다섯개만 출력 : ['가족 대한' '가족 대한 불법' '가족 대한 인신' '가족 모욕' '가족 모욕 행위']
# trigram 개수 : 593
# trigram 다섯개만 출력 : ['거의 범행' '거의 범행 일시' '경우 사실' '경우 사실 판결선고' '경우 해당']
# trigram 개수 : 12797
# trigram 다섯개만 출력 : ['가격 거래' '가격 거래 조건' '가공 공범관계' '가공 공범관계 공모' '가공 범죄']
# trigram 개수 : 378
# trigram 다섯개만 출력 : ['가납 명령' '가납 명령 형사소송법' '가납 범죄사실' '가납 범죄사실 정보통신망' '가중 형법']
# trigram 개수 : 736
# trigram 다섯개만 출력 : ['가게 삥땅' '가게 삥땅 남자' '가게 횡령' '가게 횡령 사실' '가정 현관문']
# trigram 개수 : 214
# trigram 다섯개만 출력 : ['개념 사전' '개념 사전 마음' '개정 전의' '개정 전의 규정' '거기 상고이유']
# trigram 개수 : 314
# trigram 다섯개만 출력 : ['감사 취임' '감사 취임 죄질' '강보 변호사' '강보 변호사 명종' '개입 과정']
# trigram 개수 : 1217
# trigram 다섯개만 출력 : ['가독 부호로' '가독 부호로 계속' '가독성 문서' '가독성 문서 해당' '가사 형법']
# trigram 개수 : 7407
# trigram 다섯개만 출력 : ['가격 희석' '가격 희석 방지' '가능성 경우' '가능성 경우 의혹' '가능성 대한']
# trigram 개수 : 403
# trigram 다섯개만 출력 : ['가입자 유치' '가입자 유치 수수료' '개정 신설' '개정 신설 것이므' '개정 전의']
# trigram 개수 : 968
# trigram 다섯개만 출력 : ['가납 명령' '가납 명령 형사소송법' '가납 항소' '가납 항소 이유' '가족관계 양형']
# trigram 개수 : 1877
# trigram 다섯개만 출력 : ['가감 보도' '가감 보도 사장' '가공 작성' '가공 작성 실제' '가진 국민']
# trigram 개수 : 388
# trigram 다섯개만 출력 : ['개정 전의' '개정 전의 정보통신망' '검사 대한' '검사 대한 유죄' '검사 원심판결']
# trigram 개수 : 1625
# trigram 다섯개만 출력 : ['가능성 절차' '가능성 절차 조항' '가입 제한' '가입 제한 회원' '가장 효과']
# trigram 개수 : 485
# trigram 다섯개만 출력 : ['가능성 결과' '가능성 결과 자기' '가능성 대해' '가능성 대해 심사숙고' '개인 인식']
# trigram 개수 : 366
# trigram 다섯개만 출력 : ['가해 의사' '가해 의사 내지' '개별 판단' '개별 판단 정당행위' '개정 전의']
# trigram 개수 : 3946
# trigram 다섯개만 출력 : ['가공 과정' '가공 과정 모니터링' '가공 글단' '가공 글단 중간' '가공 브라우저']
# trigram 개수 : 631
# trigram 다섯개만 출력 : ['가해 의사' '가해 의사 내지' '감안 동시' '감안 동시 표현' '거기 상고이유']
# trigram 개수 : 894
# trigram 다섯개만 출력 : ['가입 국선' '가입 국선 도법' '가입 요건' '가입 요건 가지' '가지 도헌']
# trigram 개수 : 298
# trigram 다섯개만 출력 : ['개정 다만' '개정 다만 피고인' '고등법원 환송' '고등법원 환송 상고이유' '고법 선고']
# trigram 개수 : 723
# trigram 다섯개만 출력 : ['개설 웹사이트' '개설 웹사이트 전기' '거래 통념' '거래 통념 상품' '거래 통념 자기']
# trigram 개수 : 1626
# trigram 다섯개만 출력 : ['가격 압구정' '가격 압구정 신사' '가슴 수술' '가슴 수술 추천' '가슴 전문']
# trigram 개수 : 723
# trigram 다섯개만 출력 : ['가등기 권리' '가등기 권리 처분금지가처분' '가등기 말소청구' '가등기 말소청구 소송' '가등기권 소외']
# trigram 개수 : 348
# trigram 다섯개만 출력 : ['가입 유치' '가입 유치 일정' '가입자 사람' '가입자 사람 상호' '가입자 유치']
# trigram 개수 : 713
# trigram 다섯개만 출력 : ['가능성 정도' '가능성 정도 구체성' '가치 내지' '가치 내지 평가' '가해 의사']
# trigram 개수 : 6396
# trigram 다섯개만 출력 : ['가능성 대한' '가능성 대한 인식' '가능성 무관' '가능성 무관 소외' '가능성 용인']
# trigram 개수 : 868
# trigram 다섯개만 출력 : ['가입 사실관계' '가입 사실관계 라면' '가입 이상' '가입 이상 음란물' '가입 피고인']
# trigram 개수 : 614
# trigram 다섯개만 출력 : ['가치 성적' '가치 성적 자극' '가치 지니' '가치 지니 과도' '가치 훼손']
# trigram 개수 : 2492
# trigram 다섯개만 출력 : ['가능성 기초' '가능성 기초 의심' '가방 노끈' '가방 노끈 보관' '가방 모양']
# trigram 개수 : 1150
# trigram 다섯개만 출력 : ['가의 등급' '가의 등급 분류' '가입 결정' '가입 결정 주요' '가입 남녀']
# trigram 개수 : 789
# trigram 다섯개만 출력 : ['가납 명령' '가납 명령 형사소송법' '가납 직권' '가납 직권 판단' '가량 대화']
# trigram 개수 : 1614
# trigram 다섯개만 출력 : ['가등기 거짓' '가등기 거짓 우선' '가등기 과정' '가등기 과정 피고인' '가등기 기한']
# trigram 개수 : 754
# trigram 다섯개만 출력 : ['개인정보 보호' '개인정보 보호 정보통신망' '거나 정당행위' '거나 정당행위 법리' '거나 타인']
# trigram 개수 : 614
# trigram 다섯개만 출력 : ['가슴 애무' '가슴 애무 장면' '가치 지니' '가치 지니 물의' '가치 훼손']
# trigram 개수 : 459
# trigram 다섯개만 출력 : ['가능성 대한' '가능성 대한 인식' '가능성 용인' '가능성 용인 여부' '가능성 평가']
# trigram 개수 : 736
# trigram 다섯개만 출력 : ['개정 전의' '개정 전의 사법경찰관' '거기 상고이유' '거기 상고이유 주장' '거치 사실']
# trigram 개수 : 2001
# trigram 다섯개만 출력 : ['가까이 석궁' '가까이 석궁 발사' '가까이 접근' '가까이 접근 화살' '가능성 문제']
# trigram 개수 : 746
# trigram 다섯개만 출력 : ['가까이 촬영' '가까이 촬영 대부분' '가로 등급' '가로 등급 분류' '가슴 애무']
# trigram 개수 : 362
# trigram 다섯개만 출력 : ['가능성 공연' '가능성 공연 성의' '가능성 비밀' '가능성 비밀 대화' '가능성 수도']
# trigram 개수 : 330
# trigram 다섯개만 출력 : ['개정 전의' '개정 전의 이하' '거기 상고이유' '거기 상고이유 주장' '거나 공연히']
# trigram 개수 : 1300
# trigram 다섯개만 출력 : ['가능성 의무' '가능성 의무 행정절차' '가지 요건' '가지 요건 입증' '가진 법원']
# trigram 개수 : 1491
# trigram 다섯개만 출력 : ['가족 경작' '가족 경작 용도' '가족 지출' '가족 지출 도록' '가지 조직']
# trigram 개수 : 544
# trigram 다섯개만 출력 : ['가등기 거짓' '가등기 거짓 우선' '가등기 기한' '가등기 기한 등기절차' '가등기 내용']
# trigram 개수 : 268
# trigram 다섯개만 출력 : ['가능성 기존' '가능성 기존 매체' '거기 주장' '거기 주장 채증' '검사 변호사']
# trigram 개수 : 261
# trigram 다섯개만 출력 : ['가능성 구체' '가능성 구체 사실' '가치 내지' '가치 내지 평가' '가치중립 표현']
# trigram 개수 : 2120
# trigram 다섯개만 출력 : ['가격 포커' '가격 포커 판매' '가동 지속' '가동 지속 모니터링' '가드 가동']
# trigram 개수 : 2781
# trigram 다섯개만 출력 : ['가능성 문제' '가능성 문제 사용' '가능성 자신' '가능성 자신 정상' '가능성 증대']
# trigram 개수 : 490
# trigram 다섯개만 출력 : ['개설 웹사이트' '개설 웹사이트 사용' '개설 웹사이트 웹사이트' '개설 웹사이트 화면' '결과 영향']
# trigram 개수 : 475
# trigram 다섯개만 출력 : ['각종 주제' '각종 주제 커뮤니티' '감안 객관' '감안 객관 판단' '객관 판단']
# trigram 개수 : 281
# trigram 다섯개만 출력 : ['가납 명령' '가납 명령 형사소송법' '가납 범죄사실' '가납 범죄사실 피고인' '검찰 진술조서']
# trigram 개수 : 407
# trigram 다섯개만 출력 : ['가중처벌 법률' '가중처벌 법률 형법' '각자 역할' '각자 역할 분담' '강도 공모']
# trigram 개수 : 480
# trigram 다섯개만 출력 : ['거기 상고이유' '거기 상고이유 주장' '거나 처벌' '거나 처벌 희망' '검사 상고이유']
# trigram 개수 : 390
# trigram 다섯개만 출력 : ['가감 소설' '가감 소설 내용' '가능성 여부' '가능성 여부 사실오인' '가능성 용인']
# trigram 개수 : 261
# trigram 다섯개만 출력 : ['감리원 모임' '감리원 모임 자유게시판' '객관 사실' '객관 사실 게시' '거기 검사']
# trigram 개수 : 461
# trigram 다섯개만 출력 : ['가공 비밀누설' '가공 비밀누설 성립' '개인 사생활' '개인 사생활 비밀' '거기 상고이유']
# trigram 개수 : 498
# trigram 다섯개만 출력 : ['가장 접근' '가장 접근 해석' '개인 사망' '개인 사망 자도' '개인 정보']
# trigram 개수 : 2378
# trigram 다섯개만 출력 : ['가공 작성' '가공 작성 실제' '가능성 매우' '가능성 매우 피고인' '가능성 배제']
# trigram 개수 : 976
# trigram 다섯개만 출력 : ['가지 구리시' '가지 구리시 차량' '가해 의사' '가해 의사 내지' '강행 공연히']
# trigram 개수 : 441
# trigram 다섯개만 출력 : ['가입자 전화번호' '가입자 전화번호 누구' '가입자 전화번호 정보' '가입자 주식회사' '가입자 주식회사 케이티']
# trigram 개수 : 910
# trigram 다섯개만 출력 : ['가량 성관계' '가량 성관계 미끼' '가정 마음' '가정 마음 느낌' '가정 위협']
# trigram 개수 : 1021
# trigram 다섯개만 출력 : ['가사 서비스업' '가사 서비스업 서비스업' '각종 서비스' '각종 서비스 제공' '거나 특허법']
# trigram 개수 : 424
# trigram 다섯개만 출력 : ['가해 의사' '가해 의사 내지' '감안 동시' '감안 동시 표현' '검사 피고인']
# trigram 개수 : 528
# trigram 다섯개만 출력 : ['개인 정보' '개인 정보 규정' '개인정보 대한' '개인정보 대한 정의' '거기 판결']
# trigram 개수 : 2620
# trigram 다섯개만 출력 : ['가공 글단' '가공 글단 정보' '가공 정보' '가공 정보 일부' '가납 명령']
# trigram 개수 : 714
# trigram 다섯개만 출력 : ['강원 인제군' '강원 인제군 상세' '개인정보 누설' '개인정보 누설 거나' '개인정보 누설 권한']
# trigram 개수 : 932
# trigram 다섯개만 출력 : ['가공 저장' '가공 저장 검색' '감사관실 운영' '감사관실 운영 지침' '개발 부장']
# trigram 개수 : 2471
# trigram 다섯개만 출력 : ['가감 보도' '가감 보도 사장' '가중 노역장유치' '가중 노역장유치 피고인' '가지 기사']
# trigram 개수 : 735
# trigram 다섯개만 출력 : ['가지 사정' '가지 사정 고려' '가해 의사' '가해 의사 내지' '개최 교육']
# trigram 개수 : 889
# trigram 다섯개만 출력 : ['가결 고소인' '가결 고소인 시청' '가지 피고인' '가지 피고인 고소인' '가진 인물']
# trigram 개수 : 1137
# trigram 다섯개만 출력 : ['가능성 문제' '가능성 문제 사용' '가치 평가' '가치 평가 침해' '가치판단 평가']
# trigram 개수 : 1097
# trigram 다섯개만 출력 : ['가지 사정' '가지 사정 종합' '가지 행동' '가지 행동 사실' '개인정보 개인정보']
# trigram 개수 : 423
# trigram 다섯개만 출력 : ['가입 광고' '가입 광고 내용' '가입 명목' '가입 명목 취하' '가입 명목 편취할']
# trigram 개수 : 838
# trigram 다섯개만 출력 : ['가량 중단' '가량 중단 피해' '가사 심신상실' '가사 심신상실 인정' '가사 해악']
# trigram 개수 : 723
# trigram 다섯개만 출력 : ['가의 구별' '가의 구별 표현' '가해 의사' '가해 의사 내지' '감도 판결']
# trigram 개수 : 1042
# trigram 다섯개만 출력 : ['가지 번호' '가지 번호 포함' '개인 사업체' '개인 사업체 운영' '거나 돌침대']
# trigram 개수 : 1916
# trigram 다섯개만 출력 : ['가능성 공연' '가능성 공연 성의' '가입 자만' '가입 자만 내용' '가장 공갈죄']
# trigram 개수 : 2516
# trigram 다섯개만 출력 : ['가목 나목' '가목 나목 소정' '가입 외적' '가입 외적 주로' '각각 독립']
# trigram 개수 : 970
# trigram 다섯개만 출력 : ['가정 거의' '가정 거의 교단' '가정 교단' '가정 교단 생략' '가정 파탄']
# trigram 개수 : 1040
# trigram 다섯개만 출력 : ['가로 등급' '가로 등급 분류' '가슴 애무' '가슴 애무 거나' '가입 절차']
# trigram 개수 : 625
# trigram 다섯개만 출력 : ['가능성 배제' '가능성 배제 형사재판' '가지 유죄' '가지 유죄 인정' '가지 증명력']
# trigram 개수 : 433
# trigram 다섯개만 출력 : ['가능성 사실' '가능성 사실 실제' '가중 작량감경' '가중 작량감경 형법' '가중 형법']
# trigram 개수 : 1137
# trigram 다섯개만 출력 : ['가능성 존부' '가능성 존부 당원' '가사 피고인' '가사 피고인 유죄' '감독기관 실명']
# trigram 개수 : 849
# trigram 다섯개만 출력 : ['가능성 불구' '가능성 불구 피해자' '개념 보아' '개념 보아 타인' '개념 비밀']
# trigram 개수 : 505
# trigram 다섯개만 출력 : ['가입 납부' '가입 납부 마치' '가입 명목' '가입 명목 취하' '가입 비명']
# trigram 개수 : 750
# trigram 다섯개만 출력 : ['가중 형법' '가중 형법 전단' '가지 절취' '가지 절취 증거' '갈취 피해자']
# trigram 개수 : 842
# trigram 다섯개만 출력 : ['가상공간 아이디' '가상공간 아이디 비밀번호' '감히 대위' '감히 대위 피고인' '강구 여야']
# trigram 개수 : 682
# trigram 다섯개만 출력 : ['가능성 법리' '가능성 법리 오해' '가치 증거능력' '가치 증거능력 대법원' '감정 이전']
# trigram 개수 : 414
# trigram 다섯개만 출력 : ['가해 의사' '가해 의사 내지' '객관 공공의' '객관 공공의 이익' '객관 국민']
# trigram 개수 : 646
# trigram 다섯개만 출력 : ['가장 서버' '가장 서버 컴퓨터' '간의 성관계' '간의 성관계 노골' '간의 성행위']
# trigram 개수 : 1095
# trigram 다섯개만 출력 : ['가지 확인' '가지 확인 사건' '개월 정도' '개월 정도 지난' '개인 메일']
# trigram 개수 : 1313
# trigram 다섯개만 출력 : ['가납 명령' '가납 명령 형사소송법' '가납 이유' '가납 이유 피고인' '각서 일반']
# trigram 개수 : 816
# trigram 다섯개만 출력 : ['강신욱 주심' '강신욱 주심 고현철' '개정 그대로' '개정 그대로 호의' '개정 음반']
# trigram 개수 : 1741
# trigram 다섯개만 출력 : ['가담 카니발' '가담 카니발 승용차' '가량 송금' '가량 송금 사실' '가면 피해자']
# trigram 개수 : 237
# trigram 다섯개만 출력 : ['개정 전의' '개정 전의 이하' '거기 판결' '거기 판결 결과' '검사 원심판결']
# trigram 개수 : 914
# trigram 다섯개만 출력 : ['가중 선고유예' '가중 선고유예 벌금' '가중 형법' '가중 형법 전단' '간섭 일체']
# trigram 개수 : 2465
# trigram 다섯개만 출력 : ['가능성 의무' '가능성 의무 행정절차' '가령 법원' '가령 법원 직원' '가입자 전혀']
# trigram 개수 : 454
# trigram 다섯개만 출력 : ['게시판 진정서' '게시판 진정서 제목' '게재 사람' '게재 사람 비방' '결단 입법']
# trigram 개수 : 524
# trigram 다섯개만 출력 : ['감청 대하' '감청 대하 범죄' '개인정보 규정' '개인정보 규정 정보통신서비스' '개인정보 달라']
# trigram 개수 : 656
# trigram 다섯개만 출력 : ['가입 대부분' '가입 대부분 사람' '가중 형법' '가중 형법 전단' '개발 사용']
# trigram 개수 : 628
# trigram 다섯개만 출력 : ['개설 침해' '개설 침해 사이트' '개설 회원' '개설 회원 침해' '거나 극히']
# trigram 개수 : 1643
# trigram 다섯개만 출력 : ['가량 계속' '가량 계속 반복' '가장 우측' '가장 우측 우회' '가장 진행']
# trigram 개수 : 506
# trigram 다섯개만 출력 : ['가능성 정도' '가능성 정도 구체성' '가의 구별' '가의 구별 게시물' '가치 내지']

# %% [markdown]
# 이 밑부터는 초기(221103) 테스트코드

# %%
okt = Okt()

tokenized_doc = okt.pos(doc)
tokenized_nouns = ' '.join([word[0] for word in tokenized_doc if word[1] == 'Noun'])
# Out:
# 품사 태깅 10개만 출력 : [('\n', 'Foreign'), ('【', 'Foreign'), ('피고인', 'Noun'), ('】', 'Foreign'), ('【', 'Foreign'), ('검사', 'Noun'), ('】', 'Foreign'), ('최세훈', 'Noun'), ('【', 'Foreign'), ('변호인', 'Noun')]
# 명사 추출 : 피고인 검사 최세훈 변호인 변호사 이경환 주문 피고인 징역 처 이 판결 선고 전 구금일수 위 형 산입 공소 사실 중 부동산 매물 정보 저장 파일 침해 부분 무죄 이유 범죄사실 피고인 지방법원 정보통신망 이용 촉진 및 정보보호 등 관 법률 위반 죄 징역 집행유예 선고 현재 그 유예기간 중 데 한게임 아이디 패스워드 해당 아이디 보유 사이버 포커 를 현금 목적 인터넷 사이트 회원 가입 시 대부분 사람 아이디 패스워드 사용 점 착안 보안 취약 웹사이트 해킹 회원 아이디 비밀번호 소외 공모 경 경 사이 서울 성동구 송정동 프로게이머 피시방 부동산개발 관련 정보 업체 코리아 셋 인베스트먼트 주 의 인터넷 사이트 접속 위 회사 사용 프로그램 의 실행 취약점 이용 위해 위 사이트 문서 소스코드 조작 아이디 의 문자 정보 숫자 뒤 웹서버 입력 를 실행 수 명령어 아이디 란 입력 함 위 회사 접속 접근권한 정보통신망 침입 나 경 위 프로게이머 피시방 부동산 매물 중개회사 셋 메이커 주 의 인터넷 사이트 접속 위 항 방법 위 회사 접속 접근권한 정보통신망 침입 그 무렵 장소 항 위 회사 접속 후 권한 실행 수 상태 이나 의 명령어 실행 명의 회원정보 저장 파일 다운로드 사이트 내 디렉토리 보관 정보통신망 보관 타인 비밀 침해 경 위 프로게이머 피시방 인터넷 결혼 정보 회사 주 듀오 인터넷 사이트 접속 위 항 방법 위 회사 접속 접근권한 정보통신망 침입 그 무렵 장소 항 위 회사 접속 후 권한 실행 수 상태 이나 의 명령어 실행 약 회원정보 저장 파일 다운로드 위 나 항의 디렉토리 보관 정보통신망 보관 타인 비밀 침해 경 서울 서초구 서초동 채널 피시방 재정경제부 웹서버 의 게시판 로 구성 점 알 프로그램 파일 업로드 임의 파일 실행 취약점 이용 일명 악성코드 를 게시판 업로드 후 실행 웹서버 접속 권한 획득 함 접근권한 초과 정보통신망 침입 나 그 무렵 장소 항 위 회사 웹서버 접속 후 권한 실행 명령어 소스 파일 위 회사 접속 수 아이디 비밀번호 를 정보통신망 보관 타인 비밀 침해 증거 요지 피고인 법정 진술 소외 대한 검찰 피의자신문조서 소외 대한 경찰 피의자신문조서 박정인 대한 경찰 진술조서 법령 적용 범죄사실 대한 해당 법조 정보통신망 이용 촉진 및 정보보호 등 관 법률 제 제 호 제 제 항 제 제 호 제 형법 제 경합범 가중 형법 제 전단 제 제 항 제 호 제 미결구금일수 산입 형법 제 무죄 부분 이 사건 공소 사실 중 피고인 프로게이머 피시방 부동산개발 관련 정보 업체 코리아 셋 인베스트먼트 주 의 인터넷 사이트 의 접속 후 권한 실행 수 상태 이나 의 명령어 실행 부동산 매물 정보 저장 파일 회원정보 저장 파일 오인 다운로드 정보통신망 보관 타인 비밀 침해 부분 정보통신망 이용 촉진 및 정보보호 등 관 법률 제 누구 정보통신망 보관 타인 정보 를 훼손 거나 타인 비밀 침해 도용 누설 통신망 보관 정보 정보 비밀 구분 그 보호 정도 달리 따라서 정보 경우 침해 도용 누설 등 행위 훼손 위 조항 처벌 수 것 위 조항 정 비밀 해당 그 정보 내용 사회 통념 정보 정도 비밀 로서 보호 만 내용 포함 것 피고인 다운로드 저장 부동산 매물 정보 부동산 입지조건 등 부동산 매물 정보 것 수사기록 제 쪽 그 정보 위 조항 정 비밀 해당 고 보기 위 파일 일부 시스템 파일 포함 기능 구성 위 파일 포함 시스템 파일 파일 전체 방법 일반 통용 것 위 회사 개발 사용 경우 위 파일 구성 시스템 파일 파일 전체 방법 별도 비밀 로서 보호 만 내용 포함 이상 위 파일 전체 위 조항 정 비밀 해당 고 볼 수도 것 부분 대하 여 입증 따라서 부동산 매물 정보 저장 파일 위 조항 정 비밀 해당 고 볼 수 위 사실 대하 여 무죄 선고 판사 박 이규

# %%
n_gram_range = (2, 3)

count = CountVectorizer(ngram_range=n_gram_range).fit([tokenized_nouns])
candidates = count.get_feature_names_out()

print('trigram 개수 :',len(candidates))
print('trigram 다섯개만 출력 :',candidates[:5])
# Out:
# trigram 개수 : 656
# trigram 다섯개만 출력 : ['가입 대부분' '가입 대부분 사람' '가중 형법' '가중 형법 전단' '개발 사용']

# %%
model = SentenceTransformer('sentence-transformers/xlm-r-100langs-bert-base-nli-stsb-mean-tokens')
doc_embedding = model.encode([doc])
candidate_embeddings = model.encode(candidates)

# %%
top_n = 30
distances = cosine_similarity(doc_embedding, candidate_embeddings)
keywords = [candidates[index] for index in distances.argsort()[0][-top_n:]]
print(keywords)
# Out:
# ['구금일수 산입 공소', '항의 디렉토리 보관', '선고 구금일수 산입', '서울 성동구', '포함 피고인 다운로드', '미결구금일수 산입 형법', '악성코드 게시판 업로드', '대한 경찰 피의자신문조서', '비밀 침해 서울', '박정인 대한 경찰', '서울 서초구', '송정동 프로게이머 피시방', '피고인 다운로드 저장', '업체 코리아', '정보 업체 코리아', '성동구 송정동', '이용 일명 악성코드', '사이 서울 성동구', '침해 서울 서초구', '성동구 송정동 프로게이머', '코리아 인베스트먼트', '서울 성동구 송정동', '업체 코리아 인베스트먼트', '코리아 인베스트먼트 인터넷', '전단 미결구금일수 산입', '서울 서초구 서초동', '대한 검찰 피의자신문조서', '경찰 피의자신문조서 박정인', '피의자신문조서 박정인', '피의자신문조서 박정인 대한']
